# %% [markdown]
# # Coders of Bangalore
# You ask Sam Altman for a 2.2 billion USD in funding and he makes fun of you in public
#
# He asks you where you live and finally after talking to you, gives you a challenging task
#
# Collect raw instagram data of all openai followers
#
# Answer these questions:
#
# - Who has maximum posts
# - Who has maximum followers
# - Who follows maximum people
# - How many categories (Digital creators, Non profit foundation etc do we have) of how many people do we have?
#
# You have 24 hours
#
# You then ask for data - he laughs!

# %% [markdown]
# # Data Collection
# You hire Vijyalaxmi Iyer and Sam Chandra who are from Hebbal and HSR Layout respectively
#
# HSR layout and Hebbal are far away so you set up a meeting at Rameshwaram cafe, Indiranagar

# %%
with open("finaldata.txt", encoding='utf-8') as f:
    data = f.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news\n\ntechfounder_india\n210 posts\n19K followers\n450 following\nDev Patel\nFounder\n⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io\n\ncoder_on_orr\n65 posts\n1,900 followers\n70 following\nSriram\nBackend Developer\n🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks\n\nblrdatascience_daily\n540 posts\n15.1K followers\n150 following\nBangalore DS Daily\nMedia\n📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in\n\nfrontend_with_megha\n175 posts\n8,200 followers\n95 following\nMegha Gupta\nFrontend Dev\n🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev\n\ncubbonpark_runner\n95 posts\n1,500 followers\n40 following\nAman\nLifestyle\n🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning\n\nindiranagar_food_maps\n600 posts\n12.3K followers\n155 following\nFood Maps BLR\nFood & Drink\n🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com\n\npython_blr_jobs\n1,200 posts\n21K followers\n18 following\nPython Jobs BLR\nCommunity\n💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs\n\nsarjapur_coder\n143 posts\n3,200 followers\n52 following\nRoshan\nFull-stack Dev\n🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev\n\nopen_source_blr\n300 posts\n9,100 followers\n78 following\nBLR Open Source\nCommunity\n🌐 Meetups | Talks | OSS\ngithub.com/blropensource\n\ntechwalk_blr\n430 posts\n11K followers\n320 following\nTech Walk Bangalore\nMedia\n🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com\n\nitpl_daily\n590 posts\n14.2K followers\n210 following\nITPL Daily\nBlog\n🏢 Inside Whitefield Tech Life\n🚌 Bus stand stories included\nmedium.com/@itpldaily\n\nreact_native_blr\n220 posts\n4,700 followers\n60 following\nRN Bangalore\nCommunity\n📱 React Native Tips | Meetups\nrnblr.dev\n\nfounder_doodles\n80 posts\n2,300 followers\n20 following\nKushal\nArtist + Coder\n✏️ Startup doodles\n💻 YC fanboy\nkushaldraws.com\n\nblrproductmanager\n160 posts\n6,800 followers\n110 following\nSanya | PM\nProduct Manager\n📍 Koramangala\n🔍 Breaking down apps\nsanyapm.com\n\nmachinelearning_blr\n490 posts\n17.8K followers\n140 following\nML Bangalore\nCommunity\n🤖 Workshops | Resources\nmlblr.in\n\nbengaluru_startup_recruiter\n135 posts\n5,900 followers\n300 following\nAnkita HR\nRecruiter\n🦄 Hiring for early-stage startups\n📍 Indiranagar\nankitarecruits.in\n\ncoffeeandcode_blr\n77 posts\n1,400 followers\n44 following\nAditya\nDeveloper\n☕ Coffee + VSCode = Happiness\n📍 HSR\ngithub.com/coffeeandcodeblr\n\nuiux_blr_design\n210 posts\n9,500 followers\n130 following\nUI/UX Bangalore\nDesign\n🎨 Case studies, tips, mock UI\nuiuxblr.design\n\nwhitefield_cafe_explorer\n480 posts\n7,600 followers\n250 following\nRadhika\nCafe Nerd\n☕ Whitefield cafes & reading corners\n📘 Book recs\ninstareadsblr.com\n\njslover_bangalore\n120 posts\n3,800 followers\n32 following\nJatin Codes\nEngineer\n⚡ JavaScript everything\n📍 MG Road\ngithub. ...

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
#  'ai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news',
#  'techfounder_india\n210 posts\n19K followers\n450 following\nDev Patel\nFounder\n⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io',
#  'coder_on_orr\n65 posts\n1,900 followers\n70 following\nSriram\nBackend Developer\n🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks',
#  'blrdatascience_daily\n540 posts\n15.1K followers\n150 following\nBangalore DS Daily\nMedia\n📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in',
#  'frontend_with_megha\n175 posts\n8,200 followers\n95 following\nMegha Gupta\nFrontend Dev\n🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev',
#  'cubbonpark_runner\n95 posts\n1,500 followers\n40 following\nAman\nLifestyle\n🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning',
#  'indiranagar_food_maps\n600 posts\n12.3K followers\n155 following\nFood Maps BLR\nFood & Drink\n🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com',
#  'python_blr_jobs\n1,200 posts\n21K followers\n18 following\nPython Jobs BLR\nCommunity\n💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs',
#  'sarjapur_coder\n143 posts\n3,200 followers\n52 following\nRoshan\nFull-stack Dev\n🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev',
#  'open_source_blr\n300 posts\n9,100 followers\n78 following\nBLR Open Source\nCommunity\n🌐 Meetups | Talks | OSS\ngithub.com/blropensource',
#  'techwalk_blr\n430 posts\n11K followers\n320 following\nTech Walk Bangalore\nMedia\n🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com',
#  'itpl_daily\n590 posts\n14.2K followers\n210 following\nITPL Daily\nBlog\n🏢 Inside Whitefield Tech Life\n🚌 Bus stand stories included\nmedium.com/@itpldaily',
#  'react_native_blr\n220 posts\n4,700 followers\n60 following\nRN Bangalore\nCommunity\n📱 React Native Tips | Meetups\nrnblr.dev',
#  'founder_doodles\n80 posts\n2,300 followers\n20 following\nKushal\nArtist + Coder\n✏️ Startup doodles\n💻 YC fanboy\nkushaldraws.com',
#  'blrproductmanager\n160 posts\n6,800 followers\n110 following\nSanya | PM\nProduct Manager\n📍 Koramangala\n🔍 Breaking down apps\nsanyapm.com',
#  'machinelearning_blr\n490 posts\n17.8K followers\n140 following\nML Bangalore\nCommunity\n🤖 Workshops | Resources\nmlblr.in',
#  'bengaluru_startup_recruiter\n135 posts\n5,900 followers\n300 following\nAnkita HR\nRecruiter\n🦄 Hiring for early-stage startups\n📍 Indiranagar\nankitarecruits.in',
#  'coffeeandcode_blr\n77 posts\n1,400 followers\n44 following\nAditya\nDeveloper\n☕ Coffee + VSCode = Happiness\n📍 HSR\ngithub.com/coffeeandcodeblr',
#  'uiux_blr_design\n210 posts\n9,500 followers\n130 following\nUI/UX Bangalore\nDesign\n🎨 Case studies, tips, mock UI\nuiuxblr.design',
#  'whitefield_cafe_explorer\n480 posts\n7,600 followers\n250 following\nRadhika\nCafe Nerd\n☕ Whitefield cafes & reading corners\n📘 Book recs\ninstareadsblr.com',
#  'jslover_bangalore\n120 posts\n3,800 followers\n32 following\nJatin Codes\nEngineer\n⚡ JavaScript everything\n📍 MG Road\ngithub.com/jatincodesjs',
#  'blrautotechtalk\n310 posts\n8,400 followers\n260 following\nAutoTech BLR\nMedia\n🚗 EVs | Autonomous | Mobility\n📍 Bengaluru\nautotechblr.com',
#  'deeptech_india\n900 posts\n24K followers\n290 following\nDeepTech India\nMedia\n🛠️ Indian AI + Robotics + Chips\ndeeptechindia.ai',
#  'startupdating_blr\n140 posts\n5,000 followers\n40 following\nStartup Dating\nBlog\n💔 Founders + Investors = Drama\n📍 HSR\nmedium.com/startupdatingblr',
#  'codingkannadiga\n190 posts\n7,200 followers\n150 following\nPraveen\nTech Creator\n💻 Python + Kannada Tutorials\nyoutube.com/@codingkannadiga',
#  'koramangala_hustlers\n800 posts\n18.7K followers\n300 following\nKoramangala Hustlers\nLifestyle\n💼 Startups, events, coworks\nkorahustlers.com',
#  'mlops_blr\n210 posts\n6,400 followers\n70 following\nMLOps Bangalore\nCommunity\n🛠️ ML infra | Deployments\nmlopsblr.in',
#  'producthunt_blr\n340 posts\n10.5K followers\n190 following\nProduct Hunt BLR\nMedia\n🚀 New launches from Indian builders\nproducthuntblr.com',
#  'ai_research_india\n170 posts\n8,800 followers\n60 following\nAI Research India\nEducation\n📄 Papers, datasets, repos\nairesearchindia.org',
#  'fullstack_dev_anjali\n90 posts\n2,100 followers\n35 following\nAnjali\nDeveloper\n🌈 Full-stack tutorials\n📍 BTM Layout\nanjalicodes.tech',
#  'bangalorebikecoder\n60 posts\n1,300 followers\n30 following\nVijay\nCoder\n🚴 Cycling to office, coding after\n📍 Bellandur\nstrava.com/vijayblr',
#  'codewithchai_blr\n110 posts\n3,400 followers\n50 following\nChai + Code\nLifestyle\n☕ Chai spots + dev stories\nchaiandcode.com',
#  'indiranagar_startuplab\n220 posts\n12K followers\n160 following\nStartup Lab\nCommunity\n🧪 Experiments with early-stage founders\nindiranagarstartuplab.com',
#  'pythonforkids_blr\n95 posts\n2,700 followers\n22 following\nPython Kids BLR\nEducation\n👶 Coding classes for kids\npythonforkidsblr.in',
#  'devrel_blr\n180 posts\n7,900 followers\n70 following\nDevRel Bangalore\nCommunity\n🎤 Talks | Dev advocacy | Tools\ndevrelblr.org',
#  'techpark_memes\n350 posts\n16K followers\n250 following\nTech Park Memes\nComedy\n😂 Jokes from Ecospace, Manyata & more\nbit.ly/techparkmemes',
#  'hsr_designstudio\n400 posts\n9,400 followers\n280 following\nHSR Design Studio\nDesign\n🖌️ Freelance UI/UX\n📍 HSR\nhsrdesignstudio.in',
#  'kaggler_blr\n130 posts\n4,200 followers\n40 following\nKaggle Bangalore\nData Science\n📊 Competitions, kernels\nkagglerblr.com',
#  'datascience_rider\n75 posts\n1,600 followers\n33 following\nNaman\nData Scientist\n🏍️ Rides + ML\n📍 Indiranagar\nnamanml.dev',
#  'bootcamp_blr\n310 posts\n8,600 followers\n80 following\nBangalore Bootcamp\nEducation\n👩\u200d💻 Coding bootcamps & workshops\nbootcampblr.in',
#  'buildinpublic_blr\n270 posts\n6,200 followers\n50 following\nBuild in Public BLR\nCommunity\n📈 Indie hackers & SaaS founders\nbuildinpublicblr.com',
#  'intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio',
#  '_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul',
#  'code_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a',
#  'bangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds',
#  'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants',
#  'startuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter',
#  "foodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123",
#  'venture_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck',
#  'python_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore',
#  'indiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy',
#  '\ntechtrail_blr\n340 posts\n9,100 followers\n210 following\nTech Trail Bangalore\nMedia\n🚀 Startup scoops & tech tales\n💡 Covering Koramangala, HSR & Indiranagar\n📍 BLR\nlinktr.ee/techtrailblr',
#  'koramangala_coder\n120 posts\n2,800 followers\n95 following\nKora Coder\nPersonal Blog\n💻 Daily coding challenges\n☕ Cafe-hopping + LeetCode\n📍 Koramangala\n[https://www.google.com/search?q=koramangala+coder](https://www.google.com/search?q=koramangala+coder)',
#  'blrcowork_chronicles\n480 posts\n6,700 followers\n180 following\nCowork Chronicles BLR\nCommunity\n🏢 Exploring coworking spaces\n👨\u200d💻 For freelancers & founders\n📍 Bellandur\nbit.ly/cowork-chronicles',
#  'devhub_koramangala\n210 posts\n4,500 followers\n60 following\nDevHub Koramangala\nCommunity\n👨\u200d💻 Nightly coding jams\n📚 React | Python | AI\n📍 Koramangala 5th Block\n[https://www.google.com/search?q=devhub+koramangala](https://www.google.com/search?q=devhub+koramangala)',
#  'ai_bengaluru\n150 posts\n15.2K followers\n140 following\nAI Bengaluru\nTech\n🤖 AI trends, events & demos\n📍 BLR\nai-blr.tech',
#  'frontend_blr\n95 posts\n3,900 followers\n30 following\nFrontend BLR\nCommunity\n🎨 UI/UX | Web Dev | Tailwind\n📍 Indiranagar\n[https://www.google.com/search?q=frontendblr](https://www.google.com/search?q=frontendblr)',
#  'hsr_startup_stories\n600 posts\n22K followers\n300 following\nHSR Startup Stories\nMedia\n🦄 Founder journeys from HSR\n📍 BLR\nhsrstartups.in',
#  'python_wallah_blr\n80 posts\n1,700 followers\n40 following\nPython Wallah BLR\nEducator\n🐍 Python tips daily\n📍 BTM Layout\npythonwallah.in',
#  'btm_dev_cafe\n140 posts\n2,200 followers\n120 following\nDev Café BTM\nCommunity\n☕ Coffee + Code sessions\n📍 BTM Layout\nlinktr.ee/btmdevcafe',
#  'blrautomation_club\n90 posts\n5,800 followers\n65 following\nAutomation Club BLR\nCommunity\n🛠️ RPA | Python Scripts | AI\n📍 KR Puram\n[https://www.google.com/search?q=blrautomationclub](https://www.google.com/search?q=blrautomationclub)',
#  'coding_koramangala\n70 posts\n1,350 followers\n15 following\nCoding Koramangala\nCommunity\n👨\u200d💻 Weekly coding walks\n📍 Koramangala\nbit.ly/coding-kormangala',
#  'devlife_bangalore\n430 posts\n18K followers\n450 following\nDevLife Bangalore\nBlog\n💼 Life of BLR developers\n☕ Cafes, layoffs & chai\ndevlifeblr.medium.com',
#  'cloud_blr\n160 posts\n9,400 followers\n210 following\nCloud BLR\nTech\n☁️ Cloud + DevOps content\n📍 Electronic City\ncloudblr.dev',
#  'electroniccity_coder\n100 posts\n3,100 followers\n55 following\nECity Coder\nPersonal Blog\n💻 Python backend dev\n📍 E-city Phase 1\n[https://www.google.com/search?q=ecity+coder](https://www.google.com/search?q=ecity+coder)',
#  'bangalore_datascience_club\n240 posts\n12.7K followers\n110 following\nBLR Data Science Club\nCommunity\n📊 ML sessions + Kaggle nights\n📍 MG Road WeWork\ndatascienceblr.club',
#  'blrmobiledevs\n130 posts\n4,200 followers\n80 following\nBLR Mobile Devs\nCommunity\n📱 Flutter | React Native\n📍 Indiranagar\n[https://www.google.com/search?q=blrmobiledevs](https://www.google.com/search?q=blrmobiledevs)',
#  'react_bangalore\n300 posts\n14K followers\n200 following\nReact Bangalore\nCommunity\n⚛️ React meetups & workshops\n📍 BLR\nreactblr.dev',
#  'devs_of_whitefield\n190 posts\n6,600 followers\n150 following\nWhitefield Devs\nCommunity\n💻 Tech + productivity\n📍 Whitefield\nwhitefielddevs.in',
#  'indiranagar_debugger\n75 posts\n2,000 followers\n30 following\nIndiranagar Debugger\nBlog\n🐞 Debugging life & code\n📍 Indiranagar\nbit.ly/indiranagar-debugger',
#  'koramangala_ai_meet\n85 posts\n7,400 followers\n22 following\nKora AI Meet\nCommunity\n🤖 AI jam sessions\n📍 Koramangala 1st Block\nkora-ai.club',
#  'blrit_guy\n230 posts\n5,300 followers\n200 following\nBLR IT Guy\nPublic Figure\n💼 Big Tech employee life\n📍 Manyata Tech Park\n[https://www.google.com/search?q=blr+it+guy](https://www.google.com/search?q=blr+it+guy)',
#  'startup_grind_bangalore\n1,100 posts\n38K followers\n420 following\nStartup Grind Bangalore\nCommunity\n🔥 Founder wisdom + events\n📍 BLR\nstartupgrind.com/bangalore',
#  'coding_in_indiranagar\n60 posts\n1,100 followers\n25 following\nCoding in Indiranagar\nPersonal Blog\n👨\u200d💻 Python & JS notes\n📍 100ft Road\nbit.ly/coding-indiranagar',
#  'devwalk_blr\n50 posts\n900 followers\n15 following\nDev Walk BLR\nCommunity\n🚶\u200d♂️ Walk + talk tech\n📍 Lalbagh\ndevwalk.in',
#  'bellandur_bug_hunter\n110 posts\n3,900 followers\n75 following\nBellandur Bug Hunter\nBlog\n🐛 QA life in BLR\n📍 Bellandur\ntinyurl.com/bughunterblr',
#  'blrcoders_space\n340 posts\n25K followers\n300 following\nBLR Coders Space\nCommunity\n👨\u200d💻 Coding news, memes\n📍 BLR\nblrcoders.space',
#  'nextjs_blr\n45 posts\n2,300 followers\n40 following\nNext.js Bangalore\nCommunity\n⚡ Modern web dev meetups\n📍 MG Road\nnextjsblr.dev',
#  'techpark_musings\n130 posts\n6,000 followers\n100 following\nTech Park Musings\nBlog\n🏢 Manyata | EcoSpace | Bagmane\n📍 Bangalore\nmedium.com/@techparkmusings',
#  'koramangala_freelancers\n200 posts\n4,000 followers\n70 following\nKoramangala Freelancers\nCommunity\n💻 Remote work + gigs\n📍 Koramangala\nkorafreelancers.co',
#  'blronlinejobs\n560 posts\n21K followers\n190 following\nBLR Online Jobs\nMedia\n💼 Hiring in tech daily\n📍 BLR\nblronlinejobs.in',
#  'datascience_daily_blr\n150 posts\n8,800 followers\n140 following\nDS Daily BLR\nEducation\n📊 ML tricks & resources\n📍 BLR\ndsdailyblr.com',
#  'python_koramangala\n42 posts\n850 followers\n12 following\nPython Koramangala\nCommunity\n🐍 Weekly Python tasks\n📍 Koramangala\nbit.ly/python-kora',
#  'coding_chai_bangalore\n280 posts\n10K followers\n230 following\nCoding Chai\nBlog\n☕ Code + chai\n📍 JP Nagar\ncodingchai.in',
#  'blrgitcommunity\n75 posts\n3,200 followers\n20 following\nGit Community BLR\nTech\n🔧 Git tips & collab sessions\n📍 BLR\ngitblr.dev',
#  'indiranagar_startups\n320 posts\n12.5K followers\n100 following\nIndiranagar Startups\nMedia\n🦄 Spotlight on early-stage founders\n📍 Indiranagar\nindiranagarstartups.in',
#  'machinelearning_blr\n210 posts\n19K followers\n250 following\nMachine Learning BLR\nTech\n🤖 ML articles & demos\n📍 BLR\nmlblr.tech',
#  'koramangala_script_kiddie\n55 posts\n1,050 followers\n18 following\nScript Kiddie Kora\nPersonal Blog\n💻 Learning Python & JS\n📍 Koramangala\n[https://www.google.com/search?q=script+kiddie+kora](https://www.google.com/search?q=script+kiddie+kora)',
#  'hsr_dev_buddy\n120 posts\n2,700 followers\n40 following\nHSR Dev Buddy\nCommunity\n👨\u200d💻 Peer learning club\n📍 HSR Layout\nhsrdevbuddy.in',
#  'blrcloudhackers\n140 posts\n7,900 followers\n200 following\nBLR Cloud Hackers\nTech\n☁️ AWS | Azure | GCP\n📍 BLR\ncloudhackers.in',
#  'techwriter_blr\n60 posts\n1,900 followers\n50 following\nBLR Tech Writer\nWriter\n📝 Tech explainers\n📍 Bangalore\nmedium.com/@blrtechwriter',
#  'dev_canteen_koramangala\n180 posts\n5,400 followers\n120 following\nDev Canteen\nCommunity\n🍔 Food + code meetups\n📍 Koramangala\ndevcanteen.in',
#  'pythonlady_blr\n70 posts\n4,200 followers\n35 following\nPython Lady BLR\nEducator\n🐍 Python + data tutorials\n📍 Indiranagar\npythonlady.in',
#  'bangalore_oss\n250 posts\n9,800 followers\n90 following\nBangalore Open Source\nCommunity\n🛠️ OSS projects & contributions\n📍 BLR\nossblr.dev',
#  'blr_ai_founders\n85 posts\n6,600 followers\n70 following\nBLR AI Founders\nEntrepreneur\n🤖 AI startup builders\n📍 Indiranagar\naifoundersblr.com',
#  'coders_of_bangalore\n300 posts\n17K followers\n280 following\nCoders of Bangalore\nCommunity\n👨\u200d💻 Showcasing BLR devs\n📍 BLR\ncodersofbangalore.in',
#  'dailydev_bangalore\n180 posts\n12.2K followers\n200 following\nDaily Dev Bangalore\nTech\n📝 Tips | Tools | Tutorials\n📍 BLR\ndailydevblr.co',
#  'bangalore_backend\n90 posts\n4,800 followers\n60 following\nBLR Backend Devs\nTech\n🔧 Python | Go | Node\n📍 BLR\nbackendblr.tech',
#  'ecity_techies\n140 posts\n3,900 followers\n55 following\nE-city Techies\nCommunity\n💼 Tech park life\n📍 Electronic City\necitytechies.in',
#  'fullstack_blr_club\n110 posts\n7,200 followers\n85 following\nFullstack BLR Club\nCommunity\n💻 MERN | Python | DevOps\n📍 JP Nagar\nfullstackblr.club',
#  'coding_runners_blr\n100 posts\n2,500 followers\n35 following\nCoding Runners\nCommunity\n🏃\u200d♂️ Running + coding\n📍 Cubbon Park\ncodingrunners.in',
#  'bangalore_engineers_diary\n270 posts\n8,500 followers\n120 following\nEngineers Diary BLR\nBlog\n📘 Life & tech rants\n📍 BLR\nmedium.com/@engineersdiaryblr\n']

# %%
chunks[4]
# Out:
# 'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = sep_chunk[1]
        no_of_followers = sep_chunk[2]
        no_of_following = sep_chunk[3]
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        # print(username, no_of_posts, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, 
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

    
print(parse_chunk(chunks[0]))
# Out:
# {'username': 'techie_koramangala', 'no_of_posts': '420 posts', 'no_of_followers': '9,800 followers', 'no_of_following': '310 following', 'name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'techie_koramangala', 'no_of_posts': '420 posts', 'no_of_followers': '9,800 followers', 'no_of_following': '310 following', 'name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_posts': '150 posts', 'no_of_followers': '6,300 followers', 'no_of_following': '120 following', 'name': 'Riya Codes', 'type_of_page': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_posts': '980 posts', 'no_of_followers': '22.4K followers', 'no_of_following': '95 following', 'name': 'Startup Stories HSR', 'type_of_page': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_posts': '210 posts', 'no_of_followers': '4,500 followers', 'no_of_following': '60 following', 'name': 'Naveen DevOps', 'type_of_page': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'username': 'koramangala_coffee_lover', 'no_of_posts': '300 posts', 'no_of_followers': '7,900 followers', 'no_of_following': '180 following', 'name': 'Sana B.', 'type_of_page': 'Cafe Explorer', 'bio': '☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'}, {'username': 'ai_bangalore_news', 'no_of_posts': '1,340 posts', 'no_of_followers': '38K followers', 'no_of_following': '200 following', 'name': 'AI Bangalore', 'type_of_page': 'Media', 'bio': '🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'}, {'username': 'techfounder_india', 'no_of_posts': '210 posts', 'no_of_followers': '19K followers', 'no_of_following': '450 following', 'name': 'Dev Patel', 'type_of_page': 'Founder', 'bio': '⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io'}, {'username': 'coder_on_orr', 'no_of_posts': '65 posts', 'no_of_followers': '1,900 followers', 'no_of_following': '70 following', 'name': 'Sriram', 'type_of_page': 'Backend Developer', 'bio': '🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks'}, {'username': 'blrdatascience_daily', 'no_of_posts': '540 posts', 'no_of_followers': '15.1K followers', 'no_of_following': '150 following', 'name': 'Bangalore DS Daily', 'type_of_page': 'Media', 'bio': '📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in'}, {'username': 'frontend_with_megha', 'no_of_posts': '175 posts', 'no_of_followers': '8,200 followers', 'no_of_following': '95 following', 'name': 'Megha Gupta', 'type_of_page': 'Frontend Dev', 'bio': '🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev'}, {'username': 'cubbonpark_runner', 'no_of_posts': '95 posts', 'no_of_followers': '1,500 followers', 'no_of_following': '40 following', 'name': 'Aman', 'type_of_page': 'Lifestyle', 'bio': '🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'}, {'username': 'indiranagar_food_maps', 'no_of_posts': '600 posts', 'no_of_followers': '12.3K followers', 'no_of_following': '155 following', 'name': 'Food Maps BLR', 'type_of_page': 'Food & Drink', 'bio': '🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com'}, {'username': 'python_blr_jobs', 'no_of_posts': '1,200 posts', 'no_of_followers': '21K followers', 'no_of_following': '18 following', 'name': 'Python Jobs BLR', 'type_of_page': 'Community', 'bio': '💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs'}, {'username': 'sarjapur_coder', 'no_of_posts': '143 posts', 'no_of_followers': '3,200 followers', 'no_of_following': '52 following', 'name': 'Roshan', 'type_of_page': 'Full-stack Dev', 'bio': '🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev'}, {'username': 'open_source_blr', 'no_of_posts': '300 posts', 'no_of_followers': '9,100 followers', 'no_of_following': '78 following', 'name': 'BLR Open Source', 'type_of_page': 'Community', 'bi ...

# %% [markdown]
# # Who has the maximum posts?

# %%
max_posts = 0
chunk_with_max_post = None

for chunk in all_chunks:
    raw_value = str(chunk['no_of_posts'])
    
    cleaned = raw_value.replace(' posts', '').replace(' post', '').replace(',', '')
    posts = int(cleaned)
    
    if posts > max_posts:
        max_posts = posts
        chunk_with_max_post = chunk

print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': '2,300 posts', 'no_of_followers': '45K followers', 'no_of_following': '120 following', 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# # Who has the maximum followers?

# %%
import re

max_followers = 0
chunk_with_max_followers = None

for chunk in all_chunks:
    raw_value = str(chunk['no_of_followers'])
    digits = re.sub(r'\D', '', raw_value)
    
    if digits:
        followers = int(digits)
        if followers > max_followers:
            max_followers = followers
            chunk_with_max_followers = chunk

print(chunk_with_max_followers)
# Out:
# {'username': 'techie_koramangala', 'no_of_posts': '420 posts', 'no_of_followers': '9,800 followers', 'no_of_following': '310 following', 'name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}

# %% [markdown]
# # Who follows maximum people?

# %%
max_following = 0
chunk_with_max_following = None

for chunk in all_chunks:
    raw_value = str(chunk['no_of_following'])
    digits = re.sub(r'\D', '', raw_value)  # keep only digits
    
    if digits:  # ensure not empty
        following = int(digits)
        if following > max_following:
            max_following = following
            chunk_with_max_following = chunk

print(chunk_with_max_following)
# Out:
# {'username': 'katiasales2220', 'no_of_posts': '107 posts', 'no_of_followers': '219 followers', 'no_of_following': '1,401 following', 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %% [markdown]
# # How many categories?

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(categories, len(categories))
# Out:
# {'Community', 'Nonprofit organization', 'Alfabetização e Reforço Escolar', 'Digital creator', 'Investor', 'Blogger', 'Personal Blog', 'Unknown', 'Entrepreneur', 'Media', 'Public Figure', 'Gamer', 'Food & Drink'} 13
